# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

data = pd.read_csv("C:/Users/priya/Documents/GitHub/OIBSIP/Task-2_unemployment/Unemployment in India.csv")
print(data.head())
# Out:
#            States         Date  Frequency   EUR          EE   ELPR   Area
# 0  Andhra Pradesh   31-05-2019    Monthly  3.65  11999139.0  43.24  Rural
# 1  Andhra Pradesh   30-06-2019    Monthly  3.05  11755881.0  42.05  Rural
# 2  Andhra Pradesh   31-07-2019    Monthly  3.75  12086707.0  43.50  Rural
# 3  Andhra Pradesh   31-08-2019    Monthly  3.32  12285693.0  43.97  Rural
# 4  Andhra Pradesh   30-09-2019    Monthly  5.17  12256762.0  44.68  Rural

# %%
print(data.isnull().sum())
# Out:
# States        14
#  Date         14
#  Frequency    14
#  EUR          14
# EE            14
# ELPR          14
# Area          14
# dtype: int64

# %%
data.columns= ["States","Date","Frequency","EUR","EE","ELPR","Area"]

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr())
plt.show()

# %%
# Set the column names for your data
data.columns = ["States", "Date", "Frequency", "EUR", "EE", "ELPR", "Area"]

# Set the figure size and create a new subplot
fig, ax = plt.subplots(figsize=(15, 12))

# Set the title of the plot
plt.title("Indian Unemployment")

# Create the histogram plot using Seaborn
sns.histplot(x="EE", hue="States", data=data, ax=ax)

# Display the plot
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.title("Indian Unemployment")
sns.histplot(x="EUR", hue="States", data=data)
plt.show()

# %%
unemployment = data[["Area", "States", "EUR"]]
fig_sunburst = px.sunburst(unemployment, path=["States", "Area"],
                           values="EUR",
                           color_continuous_scale="RdY1Gn",
                           title="Unemployment Rate in India")
States_unemployment = unemployment.groupby("States")["EUR"].mean()
fig_pie = go.Figure(data=[go.Pie(labels=States_unemployment.index, values=States_unemployment.values)])
fig = make_subplots(rows=1, cols=2, specs=[[{"type": "sunburst"}, {"type": "pie"}]])
fig.add_trace(fig_sunburst.data[0], row=1, col=1)
fig.add_trace(fig_pie.data[0], row=1, col=2)
fig.update_layout(title_text="Unemployment Rate in India")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19212\572506066.py in <module>
#       1 unemployment = data[["Area", "States", "EUR"]]
# ----> 2 fig_sunburst = px.sunburst(unemployment, path=["States", "Area"],
#       3                            values="EUR",
#       4                            color_continuous_scale="RdY1Gn",
#       5                            title="Unemployment Rate in India")
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539     if path is not None and branchvalues is None:
#    1540         branchvalues = "total"
# ...
